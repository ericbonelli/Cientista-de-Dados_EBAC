# %% [markdown]
# <a href="https://colab.research.google.com/github/ericbonelli/Cientista-de-Dados_EBAC/blob/main/Mod04_Tarefa_aulas_06_a_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
# 2) Seu código aqui
r = requests.get(url)

# %%
# 3) Seu código aqui
r.status_code
# Out:
# 200

# %%
data_json = r.json()
print(data_json['items'])
# Out:
# [{'id_pleito': 34298, 'tipo_interessado': 'Município', 'interessado': 'Presidente Getúlio', 'cod_ibge': 4214003, 'uf': 'SC', 'num_pvl': 'PVL02.003289/2019-17', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Estado de Santa Catarina S/A', 'moeda': 'Real', 'valor': 4000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '26/08/2019'}, {'id_pleito': 33775, 'tipo_interessado': 'Município', 'interessado': 'Monte Alto', 'cod_ibge': 3531308, 'uf': 'SP', 'num_pvl': 'PVL02.002786/2019-06', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 3039000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '23/10/2019'}, {'id_pleito': 30134, 'tipo_interessado': 'Município', 'interessado': 'Mutuípe', 'cod_ibge': 2922409, 'uf': 'BA', 'num_pvl': 'PVL02.002582/2018-86', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Estado da Bahia S/A', 'moeda': 'Real', 'valor': 2300000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '22/11/2018'}, {'id_pleito': 32133, 'tipo_interessado': 'Município', 'interessado': 'Lapa', 'cod_ibge': 4113205, 'uf': 'PR', 'num_pvl': 'PVL02.000562/2019-51', 'status': 'Deferido', 'num_processo': '17944.101678/2019-70', 'data_protocolo': '2019-05-17T12:06:24Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 5562115, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 1, 'data_status': '20/05/2019'}, {'id_pleito': 29592, 'tipo_interessado': 'Município', 'interessado': 'Bom Jesus da Lapa', 'cod_ibge': 2903904, 'uf': 'BA', 'num_pvl': 'PVL02.002123/2018-01', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Estado da Bahia S/A', 'moeda': 'Real', 'valor': 4900000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '06/09/2018'}, {'id_pleito': 30305, 'tipo_interessado': 'Município', 'interessado': 'São Caetano do Sul', 'cod_ibge': 3548807, 'uf': 'SP', 'num_pvl': 'PVL02.002525/2018-05', 'status': 'Deferido', 'num_processo': '17944.109722/2018-17', 'data_protocolo': '2018-11-29T17:35:53Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Saneamento para Todos', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 6809935.02, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 1, 'data_status': '05/12/2018'}, {'id_pleito': 30369, 'tipo_interessado': 'Município', 'interessado': 'Tijucas', 'cod_ibge': 4218004, 'uf': 'SC', 'num_pvl': 'PVL02.002182/2018-71', 'status': 'Deferido', 'num_processo': '17944.109808/2018-31', 'data_protocolo': '2019-01-30T09:40:25Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 10000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '30/01/2019'}, {'id_pleito': 30137, 'tipo_interessado': 'Município', 'interessado': 'Itajaí', 'cod_ibge': 4208203, 'uf': 'SC', 'num_pvl': 'PVL02.002543/2018-89', 'status': 'Deferido', 'num_processo': '17944.109376/2018-69', 'data_protocolo': '2018-10-25T15:35:53Z', 'tipo ...

# %%
df = pd.DataFrame(data_json['items'])
df.head(5)
# Out:
#    id_pleito tipo_interessado         interessado  cod_ibge  uf  \
# 0      34298        Município  Presidente Getúlio   4214003  SC
# 1      33775        Município          Monte Alto   3531308  SP
# 2      30134        Município             Mutuípe   2922409  BA
# 3      32133        Município                Lapa   4113205  PR
# 4      29592        Município   Bom Jesus da Lapa   2903904  BA
#
#                 num_pvl             status          num_processo  \
# 0  PVL02.003289/2019-17  Deferido (PVL-IF)                  None
# 1  PVL02.002786/2019-06  Deferido (PVL-IF)                  None
# 2  PVL02.002582/2018-86  Deferido (PVL-IF)                  None
# 3  PVL02.000562/2019-51           Deferido  17944.101678/2019-70
# 4  PVL02.002123/2018-01  Deferido (PVL-IF)                  None
#
#          data_protocolo                tipo_operacao      finalidade  \
# 0                  None  Operação contratual interna  Infraestrutura
# 1                  None  Operação contratual interna  Infraestrutura
# 2                  None  Operação contratual interna  Infraestrutura
# 3  2019-05-17T12:06:24Z  Operação contratual interna  Infraestrutura
# 4                  None  Operação contratual interna  Infraestrutura
#
#                        tipo_credor  \
# 0  Instituição Financeira Nacional
# 1  Instituição Financeira Nacional
# 2  Instituição Financeira Nacional
# 3  Instituição Financeira Nacional
# 4  Instituição Financeira Nacional
#
#                                               credor moeda      valor  \
# 0  Agência de Fomento do Estado de Santa Catarina...  Real  4000000.0
# 1                            Caixa Econômica Federal  Real  3039000.0
# 2          Agência de Fomento do Estado da Bahia S/A  Real  2300000.0
# 3                            Caixa Econômica Federal  Real  5562115.0
# 4          Agência de Fomento do Estado da Bahia S/A  Real  4900000.0
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 0                      1  26/08/2019
# 1                 0                      1  23/10/2019
# 2                 0                      1  22/11/2018
# 3                 1                      1  20/05/2019
# 4                 0                      0  06/09/2018

# %%
# 1 - Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
estadorj = df[df['uf'] == 'RJ']
estadorj.head(5)
# Out:
#      id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 38       61653        Município     Teresópolis   3305802  RJ
# 103      34099        Município         Resende   3304201  RJ
# 152      12521        Município     Nova Iguaçu   3303500  RJ
# 257       9898           Estado  Rio de Janeiro        33  RJ
# 267       7986        Município       Rio Claro   3304409  RJ
#
#                   num_pvl             status          num_processo  \
# 38   PVL02.007127/2022-53           Deferido  17944.103775/2022-01
# 103  PVL02.003090/2019-99  Deferido (PVL-IF)                  None
# 152                  None           Deferido  17944.001705/2007-71
# 257                  None           Deferido  17944.001076/2010-85
# 267                  None           Deferido  17944.000690/2010-20
#
#            data_protocolo                tipo_operacao  \
# 38   2022-10-19T16:18:08Z  Operação contratual interna
# 103                  None  Operação contratual interna
# 152  2008-03-24T00:00:00Z  Operação contratual interna
# 257  2011-05-25T00:00:00Z  Operação contratual interna
# 267  2011-06-01T00:00:00Z  Operação contratual interna
#
#                    finalidade                      tipo_credor  \
# 38             Multissetorial  Instituição Financeira Nacional
# 103         Aporte de capital  Instituição Financeira Nacional
# 152  PAC - Pró-Moradia - 2008  Instituição Financeira Nacional
# 257                     Saúde  Instituição Financeira Nacional
# 267                   Provias  Instituição Financeira Nacional
#
#                                              credor moeda         valor  \
# 38   Agência de Fomento do Estado do Rio de Janeiro  Real  3.500000e+07
# 103                         Caixa Econômica Federal  Real  4.500000e+06
# 152                         Caixa Econômica Federal  Real  1.424795e+08
# 257                             Banco do Brasil S/A  Real  1.328000e+08
# 267                             Banco do Brasil S/A  Real  6.474000e+05
#
#      pvl_assoc_divida  pvl_contradado_credor data_status
# 38                  0                      0  21/10/2022
# 103                 0                      1  27/09/2019
# 152                 1                      0  27/03/2008
# 257                 0                      0  07/06/2011
# 267                 0                      0  22/07/2011

# %%
# 2- Quais são os três status das solicitações mais frequentes na base? Quais são suas frequências?
estadorj['status'].value_counts()
# Out:
# status
# Deferido                                                 28
# Arquivado                                                14
# Encaminhado à PGFN com manifestação técnica favorável    12
# Deferido (PVL-IF)                                         6
# Regularizado                                              6
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            2
# Assinado pelo interessado (retificação)                   1
# Em retificação pelo interessado                           1
# Name: count, dtype: int64

# %%
# 3- Construa uma nova variável que contenha o ano do status. Observe que data_status vem como tipo object no DataFrame. Dica: você pode usar o método .str para transformar o tipo da variável em string, em seguida um método como slice() ou split().
estadorj.loc[:,'ano_status'] = estadorj['data_status'].str.split('/').str[-1]
estadorj.head(5)
# Out:
#      id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 38       61653        Município     Teresópolis   3305802  RJ
# 103      34099        Município         Resende   3304201  RJ
# 152      12521        Município     Nova Iguaçu   3303500  RJ
# 257       9898           Estado  Rio de Janeiro        33  RJ
# 267       7986        Município       Rio Claro   3304409  RJ
#
#                   num_pvl             status          num_processo  \
# 38   PVL02.007127/2022-53           Deferido  17944.103775/2022-01
# 103  PVL02.003090/2019-99  Deferido (PVL-IF)                  None
# 152                  None           Deferido  17944.001705/2007-71
# 257                  None           Deferido  17944.001076/2010-85
# 267                  None           Deferido  17944.000690/2010-20
#
#            data_protocolo                tipo_operacao  \
# 38   2022-10-19T16:18:08Z  Operação contratual interna
# 103                  None  Operação contratual interna
# 152  2008-03-24T00:00:00Z  Operação contratual interna
# 257  2011-05-25T00:00:00Z  Operação contratual interna
# 267  2011-06-01T00:00:00Z  Operação contratual interna
#
#                    finalidade                      tipo_credor  \
# 38             Multissetorial  Instituição Financeira Nacional
# 103         Aporte de capital  Instituição Financeira Nacional
# 152  PAC - Pró-Moradia - 2008  Instituição Financeira Nacional
# 257                     Saúde  Instituição Financeira Nacional
# 267                   Provias  Instituição Financeira Nacional
#
#                                              credor moeda         valor  \
# 38   Agência de Fomento do Estado do Rio de Janeiro  Real  3.500000e+07
# 103                         Caixa Econômica Federal  Real  4.500000e+06
# 152                         Caixa Econômica Federal  Real  1.424795e+08
# 257                             Banco do Brasil S/A  Real  1.328000e+08
# 267                             Banco do Brasil S/A  Real  6.474000e+05
#
#      pvl_assoc_divida  pvl_contradado_credor data_status ano_status
# 38                  0                      0  21/10/2022       2022
# 103                 0                      1  27/09/2019       2019
# 152                 1                      0  27/03/2008       2008
# 257                 0                      0  07/06/2011       2011
# 267                 0                      0  22/07/2011       2011

# %%
# 4- Indique a frequência de cada ano do campo construído no item (3).
estadorj['ano_status'].value_counts()
# Out:
# ano_status
# 2008    11
# 2011     8
# 2023     6
# 2019     6
# 2007     6
# 2013     5
# 2009     5
# 2012     4
# 2014     3
# 2022     3
# 2016     3
# 2020     3
# 2015     2
# 2021     2
# 2010     2
# 2024     1
# 2018     1
# 2003     1
# 2002     1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado ('Estado'ou Município), e que devolve os dados da consulta no formato DataFrame.
def consulta(uf, tipo):
  return df[(df['uf'] == uf) & (df['tipo_interessado'] == tipo)]

# %%
# 2) Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com status em 'Arquivado por decurso de prazo' estão registradas?
(consulta('MG', 'Estado').loc[:,'status'] == 'Arquivado por decurso de prazo').value_counts()
# Out:
# status
# False    6
# True     1
# Name: count, dtype: int64

# %%
# 3) município da Bahia com mais solicitações deferido
(consulta('BA', 'Município').loc[consulta('BA', 'Município')['status'] == 'Deferido', 'interessado'].value_counts())
# Out:
# interessado
# Luís Eduardo Magalhães    4
# Santo Estêvão             4
# Lauro de Freitas          3
# Barreiras                 2
# Caculé                    2
#                          ..
# Barra                     1
# Salvador                  1
# Riachão do Jacuípe        1
# Tapiramutá                1
# Brotas de Macaúbas        1
# Name: count, Length: 78, dtype: int64

# %%
# 4) Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'
consulta('BA', 'Estado').to_csv('solicitacoes_bahia.csv')
