# %% [markdown]
# <a href="https://colab.research.google.com/github/ericbonelli/Cientista-de-Dados_EBAC/blob/main/Mod04_Tarefa_aula_01_e_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os tutores
# - Divirta-se :)
#
# #### 1)  crie uma série do pandas a partir de uma lista com os dados abaixo:
#
# Em um estudo sobre alteração na tempreatura global, A NASA disponibiliza dados de diferenças de de temperatura média da superfície terrestre relativos às médias de temperatura entre 1951 e 1980. Os dados originais podem ser vistos no site da NASA/GISS, e estão dispostos a cada década na tabela abaixo.
#
# |ano|anomalia termica|
# |:-:|:----:|
# | 1900 | -0.08 |
# | 1920 | -0.27 |
# | 1940 | 0.12 |
# | 1960 | -0.03 |
# | 1980 | 0.26 |
# | 2000 | 0.40 |
# | 2020 | 1.02 |
#
# Crie uma séries do Pandas a partir de uma lista com esses dados.

# %%
import pandas as pd
import numpy as np

# Seu código aqui
anomalia_termica = [-0.08, -0.27, 0.12, -0.03, 0.26, 0.40, 1.02]
anomalia = pd.Series(anomalia_termica)
anomalia
# Out:
# 0   -0.08
# 1   -0.27
# 2    0.12
# 3   -0.03
# 4    0.26
# 5    0.40
# 6    1.02
# dtype: float64

# %% [markdown]
# #### 2) Coloque os anos nos índices conforme a tabela.

# %%
# seu código aqui
anomaliaComIndex = pd.Series([-0.08, -0.27, 0.12, -0.03, 0.26, 0.40, 1.02],
                                 index=['1900', '1920', '1940', '1960', '1980', '2000', '2020'])
anomaliaComIndex.name = 'Anomalia Térmica'
anomaliaComIndex.index.name = 'Ano'
anomaliaComIndex
# Out:
# Ano
# 1900   -0.08
# 1920   -0.27
# 1940    0.12
# 1960   -0.03
# 1980    0.26
# 2000    0.40
# 2020    1.02
# Name: Anomalia Térmica, dtype: float64

# %% [markdown]
# #### 3) A partir do dicionário abaixo, crie uma séries do Pandas:

# %%
dic_temperaturas = {1900: -.08, 1920: -.27, 1940: .12, 1960: -.03, 1980: .26, 2000: .40, 2020: 1.02}

# seu código aqui
temperaturasSerie  =  pd.Series(dic_temperaturas)
temperaturasSerie.name = 'Temperatura'
temperaturasSerie.index.name = 'Ano'
temperaturasSerie
# Out:
# Ano
# 1900   -0.08
# 1920   -0.27
# 1940    0.12
# 1960   -0.03
# 1980    0.26
# 2000    0.40
# 2020    1.02
# Name: Temperatura, dtype: float64

# %% [markdown]
# #### 4) Transforme o ndarray abaixo em um dataframe.
# O numpy é capaz de gerar arrays n-dimensionais com números pseudo-aleatórios de acordo com uma variedade de distribuições, como no exemplo abaixo. Transforme esse nd-array em um DataFrame.

# %%
arr = np.random.normal(100, 10, (20,3))

# seu código aqui
df = pd.DataFrame(arr)
df
# Out:
#              0           1           2
# 0   103.518555   92.491988  116.975546
# 1    82.956338  113.885796   97.608961
# 2   102.972370   96.836878  111.157538
# 3    95.945656  104.468916  111.435318
# 4    89.914884  108.418701  103.083047
# 5    98.484508   95.266154  104.043273
# 6    79.837543  102.507599  102.394056
# 7   111.309994  100.579797  100.203425
# 8   100.201577   87.192244  105.720887
# 9    93.744864   98.022953   97.961518
# 10   93.704873  108.753003   87.290778
# 11  110.048658  116.918135   91.026280
# 12   97.805405  102.841742   92.617266
# 13   86.212257   97.724824   95.698641
# 14   89.618496  104.984059  110.392756
# 15  103.114992   93.587160  114.968777
# 16  107.405297   98.572264   97.859635
# 17   95.507479  115.316786  105.275831
# 18   77.585443   86.508185   88.300384
# 19   99.888394   85.292242  101.632659

# %% [markdown]
# #### 5) Nomeie os índices das linhas com inteiros de 1 a 20, e as colunas com os nomes "x1", "x2", e "x3" respectivamente.

# %%
#seu código aqui
df.index = range(1, 21)
df.columns = ['x1', 'x2', 'x3']
df
# Out:
#             x1          x2          x3
# 1   103.518555   92.491988  116.975546
# 2    82.956338  113.885796   97.608961
# 3   102.972370   96.836878  111.157538
# 4    95.945656  104.468916  111.435318
# 5    89.914884  108.418701  103.083047
# 6    98.484508   95.266154  104.043273
# 7    79.837543  102.507599  102.394056
# 8   111.309994  100.579797  100.203425
# 9   100.201577   87.192244  105.720887
# 10   93.744864   98.022953   97.961518
# 11   93.704873  108.753003   87.290778
# 12  110.048658  116.918135   91.026280
# 13   97.805405  102.841742   92.617266
# 14   86.212257   97.724824   95.698641
# 15   89.618496  104.984059  110.392756
# 16  103.114992   93.587160  114.968777
# 17  107.405297   98.572264   97.859635
# 18   95.507479  115.316786  105.275831
# 19   77.585443   86.508185   88.300384
# 20   99.888394   85.292242  101.632659

# %% [markdown]
# #### 6) No DataFrame do exercício 5, crie uma nova coluna como sendo a média das três colunas, e dê a ela o nome de "media" (não recomendo colocar acentos em nomes de variáveis).

# %%
# seu código aqui
df['media'] = df.mean(axis=1)
df
# Out:
#             x1          x2          x3       media
# 1   103.518555   92.491988  116.975546  104.328696
# 2    82.956338  113.885796   97.608961   98.150365
# 3   102.972370   96.836878  111.157538  103.655595
# 4    95.945656  104.468916  111.435318  103.949963
# 5    89.914884  108.418701  103.083047  100.472211
# 6    98.484508   95.266154  104.043273   99.264645
# 7    79.837543  102.507599  102.394056   94.913066
# 8   111.309994  100.579797  100.203425  104.031072
# 9   100.201577   87.192244  105.720887   97.704903
# 10   93.744864   98.022953   97.961518   96.576445
# 11   93.704873  108.753003   87.290778   96.582884
# 12  110.048658  116.918135   91.026280  105.997691
# 13   97.805405  102.841742   92.617266   97.754804
# 14   86.212257   97.724824   95.698641   93.211907
# 15   89.618496  104.984059  110.392756  101.665104
# 16  103.114992   93.587160  114.968777  103.890310
# 17  107.405297   98.572264   97.859635  101.279066
# ...

# %% [markdown]
# #### 7) No DataFrame do exercício 6, crie uma nova coluna chamada "log_med", contendo o logaritmo natural da média calculada no exercício 6 <br>

# %%
# seu código aqui
#contendo o logaritmo natural da média
df['log_med'] = np.log(df['media'])
df
# Out:
#             x1          x2          x3       media   log_med
# 1   103.518555   92.491988  116.975546  104.328696  4.647546
# 2    82.956338  113.885796   97.608961   98.150365  4.586501
# 3   102.972370   96.836878  111.157538  103.655595  4.641074
# 4    95.945656  104.468916  111.435318  103.949963  4.643910
# 5    89.914884  108.418701  103.083047  100.472211  4.609881
# 6    98.484508   95.266154  104.043273   99.264645  4.597789
# 7    79.837543  102.507599  102.394056   94.913066  4.552961
# 8   111.309994  100.579797  100.203425  104.031072  4.644690
# 9   100.201577   87.192244  105.720887   97.704903  4.581952
# 10   93.744864   98.022953   97.961518   96.576445  4.570335
# 11   93.704873  108.753003   87.290778   96.582884  4.570402
# 12  110.048658  116.918135   91.026280  105.997691  4.663417
# 13   97.805405  102.841742   92.617266   97.754804  4.582462
# 14   86.212257   97.724824   95.698641   93.211907  4.534875
# ...
