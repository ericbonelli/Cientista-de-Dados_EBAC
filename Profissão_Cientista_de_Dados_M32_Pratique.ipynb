# %% [markdown]
# <a href="https://colab.research.google.com/github/ericbonelli/Cientista-de-Dados_EBAC/blob/main/Profissa%CC%83o_Cientista_de_Dados_M32_Pratique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidade - Tarefa

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 1. Uma máquina embala ração para cachorro em pacotes de 15 kg, mas cada pacote produzido acaba tendo um peso aleatório, com distribuição Normal, com média 15kg, mas com desvio padrão 0,1 kg. Obtenha a probabilidade de que um pacote selecionado aleatoriamente dessa produção tenha mais que 15,2 kg.

# %%
# Parâmetros da distribuição
media = 15
desvio_padrao = 0.1

# Valor desejado
x = 15.2

# Cálculo da probabilidade usando a função de sobrevivência (1 - CDF)
prob_mais_que_15_2 = stats.norm.sf(x, loc=media, scale=desvio_padrao)

print(f"A probabilidade de um pacote pesar mais que 15,2 kg é {prob_mais_que_15_2:.4f}")
# Out:
# A probabilidade de um pacote pesar mais que 15,2 kg é 0.0228

# %% [markdown]
# 2. Da máquina descrita acima, obtenha o percentil de ordem 95% para o peso dos pacotes. Ou seja, o valor tal que a probabilidade de um pacote ter peso menor que este seja de 95%.

# %%
# Percentil de ordem 95%
percentil_95 = stats.norm.ppf(0.95, loc=media, scale=desvio_padrao)

print(f"O percentil de ordem 95% para o peso dos pacotes é {percentil_95:.2f} kg")
# Out:
# O percentil de ordem 95% para o peso dos pacotes é 15.16 kg

# %% [markdown]
# 3. Suponha duas variáveis aleatórias $Y_1$ e $Y_2$, a primeira com distribuição Normal Padrão (média=0, variância=1), a segunda com distribuição *t-studdent* com 5 graus de liberdade (também padrão). Calcule, para cada uma, a probabilidade de ser menor que cada um dos valores contidos no objeto $Y$ na célula abaixo:

# %%
Y=np.linspace(-6, 6, 200)
# CDFs
cdf_normal = stats.norm.cdf(Y)
cdf_t = stats.t.cdf(Y, df=5)

# Exibir resultados como DataFrame
df_cdf = pd.DataFrame({
    'Y': Y,
    'Normal(0,1)': cdf_normal,
    't(5)': cdf_t
})

df_cdf
# Out:
#             Y   Normal(0,1)      t(5)
# 0   -6.000000  9.865876e-10  0.000923
# 1   -5.939698  1.427734e-09  0.000966
# 2   -5.879397  2.058819e-09  0.001011
# 3   -5.819095  2.958347e-09  0.001058
# 4   -5.758794  4.235851e-09  0.001108
# ..        ...           ...       ...
# 195  5.758794  1.000000e+00  0.998892
# 196  5.819095  1.000000e+00  0.998942
# 197  5.879397  1.000000e+00  0.998989
# 198  5.939698  1.000000e+00  0.999034
# 199  6.000000  1.000000e+00  0.999077
#
# [200 rows x 3 columns]

# %% [markdown]
# 4. Faça uma visualização gráfica dos dados do item anterior.

# %%
# Plotando
plt.figure(figsize=(10, 6))
plt.plot(Y, cdf_normal, label='Normal(0,1)', linewidth=2)
plt.plot(Y, cdf_t, label='t-Student (df=5)', linestyle='--', linewidth=2)
plt.title('Função de Distribuição Acumulada')
plt.xlabel('y')
plt.ylabel('P(Y < y)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5. 3. Suponha duas variáveis aleatórias $Y_1$ e $Y_2$, a primeira com distribuição Normal Padrão (média=0, variância=1), a segunda com distribuição *t-studdent* com 5 graus de liberdade (também padrão). Calcule, para cada uma, o percentil (a inversa da *CDF*) para cada um dos valores do objeto *P* abaixo:

# %%
Y=np.linspace(0, 1, 20)

# Cálculo dos quantis (inversa da CDF)
quantis_normal = stats.norm.ppf(Y)
quantis_t = stats.t.ppf(Y, df=5)

# Exibir resultados como DataFrame
df_quantis = pd.DataFrame({
    'P': Y,
    'Normal(0,1)': quantis_normal,
    't(5)': quantis_t
})

df_quantis
# Out:
#            P  Normal(0,1)      t(5)
# 0   0.000000         -inf      -inf
# 1   0.052632    -1.619856 -1.974893
# 2   0.105263    -1.252120 -1.435859
# 3   0.157895    -1.003148 -1.114396
# 4   0.210526    -0.804596 -0.876124
# 5   0.263158    -0.633640 -0.680672
# 6   0.315789    -0.479506 -0.510277
# 7   0.368421    -0.336038 -0.355328
# 8   0.421053    -0.199201 -0.209799
# 9   0.473684    -0.066012 -0.069391
# 10  0.526316     0.066012  0.069391
# 11  0.578947     0.199201  0.209799
# 12  0.631579     0.336038  0.355328
# 13  0.684211     0.479506  0.510277
# 14  0.736842     0.633640  0.680672
# 15  0.789474     0.804596  0.876124
# 16  0.842105     1.003148  1.114396
# 17  0.894737     1.252120  1.435859
# 18  0.947368     1.619856  1.974893
# 19  1.000000          inf       inf

# %% [markdown]
# 6. Faça um gráfico com os dados do item anterior.

# %%
# Plotando
plt.figure(figsize=(10, 6))
plt.plot(Y, quantis_normal, label='Normal(0,1)', marker='o')
plt.plot(Y, quantis_t, label='t-Student (df=5)', linestyle='--', marker='x')
plt.title('Quantis das Distribuições Normal e t(5)')
plt.xlabel('Probabilidade (P)')
plt.ylabel('Quantil (Inversa da CDF)')
plt.axhline(0, color='gray', linewidth=0.5)
plt.grid(True)
plt.legend()
plt.show()
